# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/dataframe.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['Address', 'Species', 'Street', 'Trap', 'AddressNumberAndStreet',
#        'NumMosquitos', 'WnvPresent', 'Day_length', 'Tmax', 'Tmin', 'Tavg',
#        'Day_length_shift', 'Tavg_shift', 'ResultSpeed', 'ResultSpeed_shift',
#        'ResultDir', 'AvgSpeed', 'ResultDir_shift', 'AvgSpeed_shift', 'Sunset',
#        'Sunrise', 'Heat', 'Depart', 'DewPoint', 'WetBulb', 'Cool', 'CodeSum',
#        'PrecipTotal', 'StnPressure'],
#       dtype='object')

# %%
df.corr()
# Out:
#                    NumMosquitos    WnvPresent    Day_length          Tmax  \
# NumMosquitos       1.000000e+00  1.968196e-01  7.114046e-02 -2.928152e-15
# WnvPresent         1.968196e-01  1.000000e+00 -8.468165e-02  9.459661e-15
# Day_length         7.114046e-02 -8.468165e-02  1.000000e+00 -1.754651e-14
# Tmax              -2.928152e-15  9.459661e-15 -1.754651e-14  1.000000e+00
# Tmin               5.351017e-15  9.733156e-15  1.182741e-14 -1.000000e+00
# Tavg               4.497848e-16 -7.719865e-15 -7.368578e-15 -1.000000e+00
# Day_length_shift   1.533813e-01  7.072474e-02  2.518794e-01 -5.616173e-13
# Tavg_shift         4.497848e-16 -7.719865e-15 -7.368578e-15 -1.000000e+00
# ResultSpeed        2.443952e-15  2.027097e-16 -2.086211e-14  1.000000e+00
# ResultSpeed_shift  5.806144e-15 -3.632230e-16  1.807787e-14  1.000000e+00
# ResultDir         -6.411109e-15 -5.514018e-15 -2.134310e-14 -1.000000e+00
# AvgSpeed          -1.322456e-14  5.530236e-15  3.661231e-15 -1.000000e+00
# ...

# %%
df.head()
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                            Species           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS    N MANDELL AVE  T007
# 2007-05-29  CULEX PIPIENS/RESTUANS     W FOSTER AVE  T015
# 2007-05-29          CULEX RESTUANS     W FOSTER AVE  T015
#
#                        AddressNumberAndStreet  NumMosquitos  WnvPresent  \
# Date
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL             1           0
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL             1           0
# ...
