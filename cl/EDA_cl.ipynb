# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/dataframe.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
#        'NumMosquitos', 'WnvPresent', 'Tmax_x', 'Tmin_x', 'Tavg_x', 'Depart_x',
#        'DewPoint_x', 'WetBulb_x', 'Heat_x', 'Cool_x', 'Sunrise_x', 'Sunset_x',
#        'CodeSum_x', 'Depth_x', 'PrecipTotal_x', 'StnPressure_x', 'SeaLevel_x',
#        'ResultSpeed_x', 'ResultDir_x', 'AvgSpeed_x', 'Tmax_y', 'Tmin_y',
#        'Tavg_y', 'Depart_y', 'DewPoint_y', 'WetBulb_y', 'Heat_y', 'Cool_y',
#        'Sunrise_y', 'Sunset_y', 'CodeSum_y', 'Depth_y', 'PrecipTotal_y',
#        'StnPressure_y', 'SeaLevel_y', 'ResultSpeed_y', 'ResultDir_y',
#        'AvgSpeed_y', 'Day_length', 'Tavg', 'Day_length_shift', 'Tavg_shift',
#        'ResultSpeed_y_shift', 'ResultDir_y_shift', 'AvgSpeed_y_shift',
#        'ResultSpeed_x_shift', 'ResultDir_x_shift', 'AvgSpeed_x_shift'],
#       dtype='object')

# %%
df['PrecipTotal_y'].value_counts()
# Out:
#  0.00    5808
# -1.00     857
#  0.06     468
#  0.01     433
#  0.36     305
#  0.83     276
#  0.02     234
#  0.03     204
#  0.20     186
#  0.13     146
#  0.88     139
#  0.23     131
#  0.92     129
#  0.59     127
#  0.84     119
#  0.11     116
#  0.12      93
#  0.09      93
#  0.19      93
#  0.87      93
#  0.04      83
#  0.44      62
#  0.17      61
#  0.16      60
#  0.27      60
#  1.19      54
#  0.08      50
#  0.46      26
# Name: PrecipTotal_y, dtype: int64

# %%
df.head()
# Out:
#             Unnamed: 0                                            Address  \
# Date
# 2007-05-29           0  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29           1  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29           2  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29           3    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29           4    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                            Species  Block           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2007-05-29          CULEX RESTUANS     62    N MANDELL AVE  T007
# 2007-05-29  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 2007-05-29          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#                        AddressNumberAndStreet   Latitude  Longitude  \
# Date
# ...

# %%
df['Day_length']
# Out:
# Date
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-05-29    1496
# 2007-06-05    1506
# 2007-06-05    1506
# 2007-06-05    1506
# 2007-06-05    1506
# 2007-06-05    1506
#               ...
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# 2013-09-26    1199
# ...

# %%
df[df.index == '2007-06-05']
# Out:
#             Unnamed: 0                                            Address  \
# Date
# 2007-06-05          25  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-06-05          26  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-06-05          27  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-06-05          28    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-06-05          29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-06-05          30   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2007-06-05          31   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2007-06-05          32   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2007-06-05          33     2500 West Grand Avenue, Chicago, IL 60654, USA
# 2007-06-05          34        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-06-05          35        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-06-05          36        1100 Roosevelt Road, Chicago, IL 60608, USA
# ...

# %%
df.index.unique()
# Out:
# Index(['2007-05-29', '2007-06-05', '2007-06-26', '2007-06-29', '2007-07-02',
#        '2007-07-11', '2007-07-18', '2007-07-19', '2007-07-25', '2007-07-27',
#        '2007-08-01', '2007-08-02', '2007-08-03', '2007-08-07', '2007-08-08',
#        '2007-08-09', '2007-08-15', '2007-08-16', '2007-08-17', '2007-08-21',
#        '2007-08-22', '2007-08-24', '2007-08-28', '2007-09-04', '2007-09-05',
#        '2007-09-06', '2007-09-12', '2007-09-18', '2007-09-19', '2007-09-24',
#        '2007-09-25', '2007-10-04', '2007-10-09', '2009-05-28', '2009-06-02',
#        '2009-06-03', '2009-06-05', '2009-06-12', '2009-06-15', '2009-06-19',
#        '2009-06-22', '2009-06-26', '2009-06-29', '2009-07-06', '2009-07-10',
#        '2009-07-13', '2009-07-17', '2009-07-24', '2009-07-27', '2009-07-31',
#        '2009-08-07', '2009-08-13', '2009-08-25', '2009-08-27', '2009-09-03',
#        '2009-09-14', '2009-09-17', '2009-09-25', '2009-10-01', '2011-06-10',
# ...

# %%
sum(df['Day_length'].isnull())
# Out:
# 0
