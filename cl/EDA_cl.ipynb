# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/dataframe.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['Address', 'Species', 'Street', 'Trap', 'AddressNumberAndStreet',
#        'NumMosquitos', 'WnvPresent', 'Day_length', 'Tmax', 'Tmin', 'Tavg',
#        'Day_length_shift', 'Tavg_shift', 'ResultSpeed', 'ResultSpeed_shift',
#        'ResultDir', 'AvgSpeed', 'ResultDir_shift', 'AvgSpeed_shift', 'Sunset',
#        'Sunrise', 'Heat', 'Depart', 'DewPoint', 'WetBulb', 'Cool', 'CodeSum',
#        'PrecipTotal', 'StnPressure'],
#       dtype='object')

# %%
df.corr()
# Out:
#                    NumMosquitos  WnvPresent  Day_length      Tmax      Tmin  \
# NumMosquitos           1.000000    0.196820    0.071140  0.159310  0.196325
# WnvPresent             0.196820    1.000000   -0.084682  0.048244  0.074048
# Day_length             0.071140   -0.084682    1.000000  0.179942  0.238243
# Tmax                   0.159310    0.048244    0.179942  1.000000  0.785216
# Tmin                   0.196325    0.074048    0.238243  0.785216  1.000000
# Tavg                   0.187541    0.064256    0.219781  0.950719  0.938078
# Day_length_shift       0.153381    0.070725    0.251879  0.472377  0.565114
# Tavg_shift             0.124675    0.088897   -0.087166  0.278268  0.312613
# ResultSpeed            0.003658   -0.046298    0.088805 -0.046229  0.018924
# ResultSpeed_shift     -0.056444   -0.088235    0.299927 -0.064050 -0.118545
# ResultDir             -0.033674    0.000175   -0.049877  0.153571  0.090473
# ...

# %%
df.head(30)
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA
# 2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA
# 2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA
# 2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA
# 2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA
# 2007-05-29     2200 West 113th Street, Chicago, IL 60643, USA
# ...
