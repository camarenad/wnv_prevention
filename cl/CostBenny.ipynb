# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance

# %%
spray = pd.read_csv('../data/spray.csv',index_col = 0)
train = pd.read_csv('../data/train.csv', index_col = 0)
train_2013 = pd.read_csv('../data/train_2013.csv', index_col=0)

# %%
spray_lat = list(spray.Latitude)

# %%
spray_long = list(spray.Longitude)

# %%
train_lat = list(train.Latitude)

# %%
train_long = list(train.Longitude)

# %%
train_lat
# Out:
# [41.95469,
#  41.95469,
#  41.994991,
#  41.974089,
#  41.974089,
#  41.9216,
#  41.891118,
#  41.867108,
#  41.867108,
#  41.896282,
#  41.919343,
#  41.921965,
#  41.921965,
#  41.688324,
#  41.688324,
#  41.862292,
#  41.720848,
#  41.731922,
#  41.731922,
#  41.891126,
#  41.891126,
#  41.999128999999996,
#  42.01743,
#  41.907645,
#  41.732984,
#  41.95469,
#  41.95469,
#  41.95469,
#  41.974089,
#  41.974089,
#  41.9216,
#  41.9216,
#  41.9216,
#  41.891118,
#  41.867108,
#  41.867108,
#  41.867108,
#  41.896282,
#  41.919343,
#  41.919343,
#  41.921965,
#  41.688324,
#  41.720848,
#  41.731922,
#  41.731922,
#  41.731922,
#  41.999128999999996,
#  41.999128999999996,
#  41.907645,
#  41.732984,
#  41.981964000000005,
#  41.944869,
#  42.011601,
#  41.94983,
#  41.979243,
#  41.986921,
#  41.801497999999995,
#  41.906638,
#  41.723195000000004,
#  41.868077,
#  41.868077,
#  41.869215999999994,
#  41.662014,
#  41.662014,
#  41.662014,
#  41.961743,
#  41.961743,
#  41.953067,
# ...

# %%
def same_lat(spray_lat,train_lat):
    for i in range(len(spray_lat)):
        same = []
        for j in range(len(train_lat)):
            if spray_lat[i] == train_lat[j]:
                same.append(spray_lat[i])
    return same

# %%
same_lat(spray_lat,train_lat)
# Out:
# []

# %%
same_lat(spray_long,train_long)
# Out:
# []

# %%
spray.index.value_counts()
# Out:
# 2013-08-15    2668
# 2013-08-29    2302
# 2013-07-17    2202
# 2011-09-07    2114
# 2013-07-25    1607
# 2013-08-22    1587
# 2013-08-08    1195
# 2013-09-05     924
# 2013-08-16     141
# 2011-08-29      95
# Name: Date, dtype: int64

# %%
def same_lat(spray_lat,train_lat):
    for i in range(len(spray_lat)):
        same = []
        for j in range(len(train_lat)):
            if abs(spray_lat[i] - train_lat[j]) < .1 :
                same.append(spray_lat[i])
    return same

# %%
same_lat(spray_lat,train_lat)
# Out:
# [42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
#  42.004805,
# ...
