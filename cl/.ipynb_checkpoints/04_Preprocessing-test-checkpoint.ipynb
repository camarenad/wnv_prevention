# %%
from sklearn.model_selection import train_test_split
import numpy as np 
import pandas as pd
import pickle
from sklearn.model_selection import TimeSeriesSplit

# %%
df = pd.read_csv('../data/test_final_dataframe_features.csv',index_col=0)

# %%
df.drop(['CodeSum','Address','Block','AddressNumberAndStreet','AddressAccuracy'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Id', 'Species', 'Street', 'Trap', 'Latitude', 'Longitude',
#        'Day_length', 'Tmax', 'Tmin', 'Tavg', 'ResultSpeed', 'ResultDir',
#        'AvgSpeed', 'Sunset', 'Sunrise', 'Heat', 'Depart', 'DewPoint',
#        'WetBulb', 'Cool', 'PrecipTotal', 'StnPressure', 'Month',
#        'Day_length_exp', 'Tavg_shift', 'Heat_exp', 'Cool_shift', 'Tmax_shift',
#        'Tmin_shift', 'Depart_shift', 'ResultSpeed_shift', 'ResultDir_exp',
#        'PrecipTotal_exp', 'WetBulb_shift', 'DewPoint_shift'],
#       dtype='object')

# %%
df_object = pd.get_dummies(df[['Trap','Species']],columns = df[['Trap','Species']].columns)

# %%
df_object.shape
# Out:
# (116187, 157)

# %%
df = pd.concat([df,df_object], axis=1, join = 'outer')

# %%
df.drop(['Trap', 'Species'], axis=1, inplace = True)

# %%
df.head()
# Out:
#              Id          Street   Latitude  Longitude  Day_length  Tmax  Tmin  \
# Date
# 2008-06-11  107   N STREETER DR  41.891126  -87.61156       54600  86.0  63.5
# 2008-06-11  108   N STREETER DR  41.891126  -87.61156       54600  86.0  63.5
# 2008-06-11  109   N STREETER DR  41.891126  -87.61156       54600  86.0  63.5
# 2008-06-11  110   N STREETER DR  41.891126  -87.61156       54600  86.0  63.5
# 2008-06-11  111   N STREETER DR  41.891126  -87.61156       54600  86.0  63.5
#
#             Tavg  ResultSpeed  ResultDir            ...              \
# Date                                                ...
# 2008-06-11  75.0         9.15       18.0            ...
# 2008-06-11  75.0         9.15       18.0            ...
# 2008-06-11  75.0         9.15       18.0            ...
# 2008-06-11  75.0         9.15       18.0            ...
# 2008-06-11  75.0         9.15       18.0            ...
#
#             Trap_T900  Trap_T903  Species_CULEX ERRATICUS  \
# Date
# 2008-06-11          0          0                        0
# 2008-06-11          0          0                        0
# 2008-06-11          0          0                        0
# 2008-06-11          0          0                        0
# 2008-06-11          0          0                        0
#
#             Species_CULEX PIPIENS  Species_CULEX PIPIENS/RESTUANS  \
# Date
# 2008-06-11                      1                               0
# 2008-06-11                      0                               0
# 2008-06-11                      0                               0
# 2008-06-11                      0                               0
# 2008-06-11                      0                               0
#
#             Species_CULEX RESTUANS  Species_CULEX SALINARIUS  \
# Date
# 2008-06-11                       0                         0
# 2008-06-11                       0                         1
# 2008-06-11                       0                         0
# 2008-06-11                       0                         0
# 2008-06-11                       0                         0
#
#             Species_CULEX TARSALIS  Species_CULEX TERRITANS  \
# Date
# 2008-06-11                       0                        0
# 2008-06-11                       0                        0
# 2008-06-11                       0                        1
# 2008-06-11                       1                        0
# 2008-06-11                       0                        0
#
#             Species_UNSPECIFIED CULEX
# Date
# 2008-06-11                          0
# 2008-06-11                          0
# 2008-06-11                          0
# 2008-06-11                          0
# 2008-06-11                          1
#
# [5 rows x 190 columns]

# %%
df.to_csv('../data/test_final_dataframe_features.csv')
