# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/test_dataframe.csv',index_col=0, parse_dates=['Date'])
weather = pd.read_csv('../data/clean_weather.csv', index_col=0)

# %%
df
# Out:
#                 Id                                            Address  \
# Date
# 2008-06-11       1  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       2  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       3  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       4  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       5  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       6  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       7  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       8  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11       9  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11      10  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11      11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11      12  6200 North Mandell Avenue, Chicago, IL 60646, USA
# ...

# %%
df['Month'] = df.index.map(lambda x: x.month)

# %%
df.to_csv('../data/test_final_dataframe.csv')
