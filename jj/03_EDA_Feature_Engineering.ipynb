# %% [markdown]
# # EDA: Feature Engineering
#
# Description: Engineering features to further refine our data, and ready it for Preprocessing.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/final_dataframe.csv', index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#    Trap                 Species  NumMosquitos  WnvPresent  Day_length  Tmax  \
# 0  T002  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 1  T002          CULEX RESTUANS             1           0       53760  88.0
# 2  T007          CULEX RESTUANS             1           0       53760  88.0
# 3  T015  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 4  T015          CULEX RESTUANS             4           0       53760  88.0
#
#    Tmin  Tavg  ResultSpeed  ResultDir  ...    Heat  Depart  DewPoint  Cool  \
# 0  62.5  75.5          5.8       17.0  ...     0.0      10  53.45788  10.5
# 1  62.5  75.5          5.8       17.0  ...     0.0      10  53.45788  10.5
# 2  62.5  75.5          5.8       17.0  ...     0.0      10  53.45788  10.5
# 3  62.5  75.5          5.8       17.0  ...     0.0      10  53.45788  10.5
# 4  62.5  75.5          5.8       17.0  ...     0.0      10  53.45788  10.5
#
#    CodeSum  PrecipTotal StnPressure   Latitude  Longitude  Month
# 0    BR HZ          0.0      29.415  41.954690 -87.800991      5
# 1    BR HZ          0.0      29.415  41.954690 -87.800991      5
# 2    BR HZ          0.0      29.415  41.994991 -87.769279      5
# 3    BR HZ          0.0      29.415  41.974089 -87.824812      5
# 4    BR HZ          0.0      29.415  41.974089 -87.824812      5
#
# [5 rows x 22 columns]

# %% [markdown]
# **Adding Rolling & Expanded Means for Features -w- Shifted Dates**

# %%
df['Day_length_exp'] = df['Day_length'].expanding().mean()

# %%
df['Tavg_shift'] = df['Tavg'].rolling(1).mean().shift(7)
df.loc[0:6, 'Tavg_shift'] = df.loc[7, 'Tavg_shift']

# %%
df['Heat_exp'] = df['Heat'].expanding().mean()

# %%
df['Cool_shift'] = df['Cool'].rolling(1).mean().shift(7)
df.loc[0:6, 'Cool_shift'] = df.loc[7, 'Cool_shift']

# %%
df['Tmax_shift'] = df['Tmax'].rolling(1).mean().shift(7)
df.loc[0:6, 'Tmax_shift'] = df.loc[7, 'Tmax_shift']

# %%
df['Tmin_shift'] = df['Tmin'].rolling(1).mean().shift(10)
df.loc[0:9, 'Tmin_shift'] = df.loc[10, 'Tmin_shift']

# %%
df['Depart_shift'] = df['Depart'].rolling(1).mean().shift(7)
df.loc[0:6, 'Depart_shift'] = df.loc[7, 'Tmin_shift']

# %%
df['ResultSpeed_shift'] = df['ResultSpeed'].rolling(1).mean().shift(28)
df.loc[0:27, 'ResultSpeed_shift'] = df.loc[28, 'ResultSpeed_shift']

# %%
df['ResultDir_exp'] = df['ResultDir'].expanding().mean()

# %%
df['PrecipTotal_exp'] = df['PrecipTotal'].expanding().mean()

# %%
# df['WetBulb_exp'] = df['WetBulb'].expanding().mean()

# %% [markdown]
# **Checking Resultant DataFrame**

# %%
df.head()
# Out:
#    Trap                 Species  NumMosquitos  WnvPresent  Day_length  Tmax  \
# 0  T002  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 1  T002          CULEX RESTUANS             1           0       53760  88.0
# 2  T007          CULEX RESTUANS             1           0       53760  88.0
# 3  T015  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 4  T015          CULEX RESTUANS             4           0       53760  88.0
#
#    Tmin  Tavg  ResultSpeed  ResultDir       ...         Day_length_exp  \
# 0  62.5  75.5          5.8       17.0       ...                53760.0
# 1  62.5  75.5          5.8       17.0       ...                53760.0
# 2  62.5  75.5          5.8       17.0       ...                53760.0
# 3  62.5  75.5          5.8       17.0       ...                53760.0
# 4  62.5  75.5          5.8       17.0       ...                53760.0
#
#    Tavg_shift  Heat_exp  Cool_shift  Tmax_shift  Tmin_shift Depart_shift  \
# 0        75.5       0.0        10.5        88.0        62.5         62.5
# 1        75.5       0.0        10.5        88.0        62.5         62.5
# 2        75.5       0.0        10.5        88.0        62.5         62.5
# 3        75.5       0.0        10.5        88.0        62.5         62.5
# 4        75.5       0.0        10.5        88.0        62.5         62.5
#
#    ResultSpeed_shift  ResultDir_exp  PrecipTotal_exp
# 0                5.8           17.0              0.0
# 1                5.8           17.0              0.0
# 2                5.8           17.0              0.0
# 3                5.8           17.0              0.0
# 4                5.8           17.0              0.0
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (8643, 32)

# %%
df.shape
# Out:
# (8643, 32)

# %%
df.head()
# Out:
#    Trap                 Species  NumMosquitos  WnvPresent  Day_length  Tmax  \
# 0  T002  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 1  T002          CULEX RESTUANS             1           0       53760  88.0
# 2  T007          CULEX RESTUANS             1           0       53760  88.0
# 3  T015  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 4  T015          CULEX RESTUANS             4           0       53760  88.0
#
#    Tmin  Tavg  ResultSpeed  ResultDir       ...         Day_length_exp  \
# 0  62.5  75.5          5.8       17.0       ...                53760.0
# 1  62.5  75.5          5.8       17.0       ...                53760.0
# 2  62.5  75.5          5.8       17.0       ...                53760.0
# 3  62.5  75.5          5.8       17.0       ...                53760.0
# 4  62.5  75.5          5.8       17.0       ...                53760.0
#
#    Tavg_shift  Heat_exp  Cool_shift  Tmax_shift  Tmin_shift Depart_shift  \
# 0        75.5       0.0        10.5        88.0        62.5         62.5
# 1        75.5       0.0        10.5        88.0        62.5         62.5
# 2        75.5       0.0        10.5        88.0        62.5         62.5
# 3        75.5       0.0        10.5        88.0        62.5         62.5
# 4        75.5       0.0        10.5        88.0        62.5         62.5
#
#    ResultSpeed_shift  ResultDir_exp  PrecipTotal_exp
# 0                5.8           17.0              0.0
# 1                5.8           17.0              0.0
# 2                5.8           17.0              0.0
# 3                5.8           17.0              0.0
# 4                5.8           17.0              0.0
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['Trap', 'Species', 'NumMosquitos', 'WnvPresent', 'Day_length', 'Tmax',
#        'Tmin', 'Tavg', 'ResultSpeed', 'ResultDir', 'AvgSpeed', 'Sunset',
#        'Heat', 'Depart', 'DewPoint', 'Cool', 'CodeSum', 'PrecipTotal',
#        'StnPressure', 'Latitude', 'Longitude', 'Month', 'Day_length_exp',
#        'Tavg_shift', 'Heat_exp', 'Cool_shift', 'Tmax_shift', 'Tmin_shift',
#        'Depart_shift', 'ResultSpeed_shift', 'ResultDir_exp',
#        'PrecipTotal_exp'],
#       dtype='object')

# %%
df.to_csv('../data/final_dataframe_features.csv')
