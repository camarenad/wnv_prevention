# %% [markdown]
# # Feature Engineering
#
# Description: Engineering features to further refine our data, and ready it for Preprocessing.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/final_dataframe.csv', index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#    Trap                 Species  NumMosquitos  WnvPresent  Day_length  Tmax  \
# 0  T002  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 1  T002          CULEX RESTUANS             1           0       53760  88.0
# 2  T007          CULEX RESTUANS             1           0       53760  88.0
# 3  T015  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 4  T015          CULEX RESTUANS             4           0       53760  88.0
#
#    Tmin  Tavg  ResultSpeed  ResultDir  ...    DewPoint  WetBulb  Cool  \
# 0  62.5  75.5          5.8       17.0  ...    53.45788     65.5  10.5
# 1  62.5  75.5          5.8       17.0  ...    53.45788     65.5  10.5
# 2  62.5  75.5          5.8       17.0  ...    53.45788     65.5  10.5
# 3  62.5  75.5          5.8       17.0  ...    53.45788     65.5  10.5
# 4  62.5  75.5          5.8       17.0  ...    53.45788     65.5  10.5
#
#    CodeSum  PrecipTotal  StnPressure        Date   Latitude  Longitude  Month
# 0    BR HZ          0.0       29.415  2007-05-29  41.954690 -87.800991      5
# 1    BR HZ          0.0       29.415  2007-05-29  41.954690 -87.800991      5
# 2    BR HZ          0.0       29.415  2007-05-29  41.994991 -87.769279      5
# 3    BR HZ          0.0       29.415  2007-05-29  41.974089 -87.824812      5
# 4    BR HZ          0.0       29.415  2007-05-29  41.974089 -87.824812      5
#
# [5 rows x 25 columns]

# %% [markdown]
# **Adding Rolling & Expanded Means for Features -w- Shifted Dates**

# %%
df['Day_length_exp'] = df['Day_length'].expanding().mean()

# %%
df['Tavg_shift'] = df['Tavg'].rolling(1).mean().shift(7)

# %%
df['Heat_exp'] = df['Heat'].expanding().mean()

# %%
df['Cool_shift'] = df['Cool'].rolling(1).mean().shift(7)

# %%
df['Tmax_shift'] = df['Tmax'].rolling(1).mean().shift(7)

# %%
df['Tmin_shift'] = df['Tmin'].rolling(1).mean().shift(10)

# %%
df['Depart_shift'] = df['Depart'].rolling(1).mean().shift(7)

# %%
df['ResultSpeed_shift'] = df['ResultSpeed'].rolling(1).mean().shift(28)

# %%
df['ResultDir_exp'] = df['ResultDir'].expanding().mean()

# %%
df['PrecipTotal_exp'] = df['PrecipTotal'].expanding().mean()

# %%
df['WetBulb_shift'] = df['WetBulb'].rolling(100).mean().shift(7)

# %%
df['DewPoint_shift'] = df['DewPoint'].rolling(9).mean().shift(74)

# %% [markdown]
# **Checking Resultant DataFrame**

# %%
df.head()
# Out:
#    Trap                 Species  NumMosquitos  WnvPresent  Day_length  Tmax  \
# 0  T002  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 1  T002          CULEX RESTUANS             1           0       53760  88.0
# 2  T007          CULEX RESTUANS             1           0       53760  88.0
# 3  T015  CULEX PIPIENS/RESTUANS             1           0       53760  88.0
# 4  T015          CULEX RESTUANS             4           0       53760  88.0
#
#    Tmin  Tavg  ResultSpeed  ResultDir       ...        Heat_exp  Cool_shift  \
# 0  62.5  75.5          5.8       17.0       ...             0.0         NaN
# 1  62.5  75.5          5.8       17.0       ...             0.0         NaN
# 2  62.5  75.5          5.8       17.0       ...             0.0         NaN
# 3  62.5  75.5          5.8       17.0       ...             0.0         NaN
# 4  62.5  75.5          5.8       17.0       ...             0.0         NaN
#
#    Tmax_shift  Tmin_shift  Depart_shift  ResultSpeed_shift  ResultDir_exp  \
# 0         NaN         NaN           NaN                NaN           17.0
# 1         NaN         NaN           NaN                NaN           17.0
# 2         NaN         NaN           NaN                NaN           17.0
# 3         NaN         NaN           NaN                NaN           17.0
# 4         NaN         NaN           NaN                NaN           17.0
#
#    PrecipTotal_exp WetBulb_shift  DewPoint_shift
# 0              0.0           NaN             NaN
# 1              0.0           NaN             NaN
# 2              0.0           NaN             NaN
# 3              0.0           NaN             NaN
# 4              0.0           NaN             NaN
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (8643, 37)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (8537, 37)

# %%
df.head()
# Out:
#      Trap                 Species  NumMosquitos  WnvPresent  Day_length  Tmax  \
# 106  T033  CULEX PIPIENS/RESTUANS             2           0       54780  91.5
# 107  T033          CULEX RESTUANS             3           0       54780  91.5
# 108  T034          CULEX RESTUANS             1           0       54780  91.5
# 109  T037          CULEX RESTUANS             1           0       54780  91.5
# 110  T040  CULEX PIPIENS/RESTUANS             5           0       54780  91.5
#
#      Tmin  Tavg  ResultSpeed  ResultDir       ...        Heat_exp  Cool_shift  \
# 106  71.5  81.5          6.7       21.5       ...        4.845794        16.5
# 107  71.5  81.5          6.7       21.5       ...        4.800926        16.5
# 108  71.5  81.5          6.7       21.5       ...        4.756881        16.5
# 109  71.5  81.5          6.7       21.5       ...        4.713636        16.5
# 110  71.5  81.5          6.7       21.5       ...        4.671171        16.5
#
#      Tmax_shift  Tmin_shift  Depart_shift  ResultSpeed_shift  ResultDir_exp  \
# 106        91.5        71.5          10.0                5.7      10.471963
# 107        91.5        71.5          10.0                5.7      10.574074
# 108        91.5        71.5          10.0                5.7      10.674312
# 109        91.5        71.5          10.0                5.7      10.772727
# 110        91.5        71.5          10.0                5.7      10.869369
#
#      PrecipTotal_exp WetBulb_shift  DewPoint_shift
# 106         0.212383        57.870        53.45788
# 107         0.211157        57.935        53.45788
# 108         0.209954        58.000        53.45788
# 109         0.208773        58.065        53.45788
# 110         0.207613        58.130        53.45788
#
# [5 rows x 37 columns]

# %%
df.to_csv('../data/final_dataframe_features.csv')
