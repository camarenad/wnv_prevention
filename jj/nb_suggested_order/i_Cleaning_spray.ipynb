# %% [markdown]
# # Appendix i - Cleaning: Spray Data
#
# Description: Ensuring the spray data has been cleaned, and ready for potential merging with our other datasets.
#
# *To Note: We decided to merge the date and time columns into a new pandas date time object.
# In the end we opted not to use the spray data as a consideration in the modeling process. The data was used to plot
# the frequency of spray by year and location. This was taken into account in the cost benefit analysis.*

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/spray.csv')

# %% [markdown]
# # Checking the shape

# %%
df.shape
# Out:
# (14835, 4)

# %% [markdown]
# # Inspecting the columns

# %%
df.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %% [markdown]
# # Dropping nan values

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date         0
# Time         0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
df.shape
# Out:
# (14251, 4)

# %% [markdown]
# # Making a new datetime column
# Here I made a dateime column and specified the type as a pandas datetime obejct.

# %%
df["DateTime"] = df.Date + " " + df.Time

# %%
df.DateTime.head()
# Out:
# 0    2011-08-29 6:56:58 PM
# 1    2011-08-29 6:57:08 PM
# 2    2011-08-29 6:57:18 PM
# 3    2011-08-29 6:57:28 PM
# 4    2011-08-29 6:57:38 PM
# Name: DateTime, dtype: object

# %%
df['DateTime']= pd.to_datetime(df['DateTime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14251 entries, 0 to 14834
# Data columns (total 5 columns):
# Date         14251 non-null object
# Time         14251 non-null object
# Latitude     14251 non-null float64
# Longitude    14251 non-null float64
# DateTime     14251 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 668.0+ KB

# %%
df.drop(['Time'],axis=1,inplace=True)

# %% [markdown]
# # Checking the columns

# %%
df.head()
# Out:
#          Date   Latitude  Longitude            DateTime
# 0  2011-08-29  42.391623 -88.089163 2011-08-29 18:56:58
# 1  2011-08-29  42.391348 -88.089163 2011-08-29 18:57:08
# 2  2011-08-29  42.391022 -88.089157 2011-08-29 18:57:18
# 3  2011-08-29  42.390637 -88.089158 2011-08-29 18:57:28
# 4  2011-08-29  42.390410 -88.088858 2011-08-29 18:57:38

# %% [markdown]
# # Checking the types
# Double checking the the DateTime column type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14251 entries, 0 to 14834
# Data columns (total 4 columns):
# Date         14251 non-null object
# Latitude     14251 non-null float64
# Longitude    14251 non-null float64
# DateTime     14251 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 556.7+ KB

# %% [markdown]
# # Checking the unique values
# Here I wanted to see the range of dates in the data.

# %%
df.DateTime.unique()
# Out:
# array(['2011-08-29T18:56:58.000000000', '2011-08-29T18:57:08.000000000',
#        '2011-08-29T18:57:18.000000000', ...,
#        '2013-09-05T20:35:21.000000000', '2013-09-05T20:35:31.000000000',
#        '2013-09-05T20:35:41.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# # Inspecting the duplicated values.

# %%
df[df.duplicated()]
# Out:
#             Date   Latitude  Longitude            DateTime
# 485   2011-09-07  41.983917 -87.793088 2011-09-07 19:43:40
# 490   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 491   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 492   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 493   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 494   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 495   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 496   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 497   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 498   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 499   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 500   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 501   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 502   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 503   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 504   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 505   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 506   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 507   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 508   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 509   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 510   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 511   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 512   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 513   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 514   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 515   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 516   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 517   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 518   2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# ...          ...        ...        ...                 ...
# 1000  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1001  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1002  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1003  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1004  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1005  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1006  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1007  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1008  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1009  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1010  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1011  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1012  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1013  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1014  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1015  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1016  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1017  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1018  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1019  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1020  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1021  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1022  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1023  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1024  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1025  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1026  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1027  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1028  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
# 1029  2011-09-07  41.986460 -87.794225 2011-09-07 19:44:32
#
# [541 rows x 4 columns]

# %%
df.Date.unique()
# Out:
# array(['2011-08-29', '2011-09-07', '2013-07-17', '2013-07-25',
#        '2013-08-08', '2013-08-15', '2013-08-16', '2013-08-22',
#        '2013-08-29', '2013-09-05'], dtype=object)

# %% [markdown]
# # Exporting the data as a csv

# %%
df.to_csv('../data/updated_spray.csv')
